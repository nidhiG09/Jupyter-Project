# %% [markdown]
# # Expressions

# %%
# Addition operation expression
43+60+16+41
# Out:
# 160

# %%
# Subtraction operation expression
50-60
# Out:
# -10

# %%
# Multiplication operation expression
5*5
# Out:
# 25

# %%
# division operation expression
25/6
# Out:
# 4.166666666666667

# %%
# Integer division operation expression
25//5
# Out:
# 5

# %%
# Result will be rounded down to the nearest integer
25//6
# Out:
# 4

# %%
30+2*60
# Out:
# 150

# %%
(30+2)*60
# Out:
# 1920

# %% [markdown]
# # Variables

# %%
# Store value into variables
x=43+20+16+41

# %%
# Print out the value in variable
x=120

# %%
# Use another variable to store the result of the operation between variable andvalue
y=x/60

# %%
# Overwrite variable with new value
x=x/60
x
# Out:
# 2.0

# %%
# Name the variables meaningfully
total_min=43+42+57
total_min
# Out:
# 142

# %%
total_hours = total_min/60
total_hours
# Out:
# 2.3666666666666667

# %%
# Complicated expression
total_hours = (43+42+57)/60
total_hours
# Out:
# 2.3666666666666667

# %%
30+20-40
# Out:
# 10

# %%
(55-5)/10
# Out:
# 5.0

# %%
(6*10)/12
# Out:
# 5.0

# %%
x = 3+2*2
x
# Out:
# 7

# %%
y = (3+2)*2
y
# Out:
# 10

# %%
z = x+y
z
# Out:
# 17
