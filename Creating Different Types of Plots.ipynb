# %%
# Importing libraries
from matplotlib import pyplot as plt
# OR
# import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ## matplotlib functions

# %% [markdown]
# 1. Standarad Line Plot

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d8b592bf313e> in <cell line: 1>()
# ----> 1 plt.plot(x,y)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 2. Scatter Plot

# %%
plt.scatter(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-964dc56e0d0d> in <cell line: 1>()
# ----> 1 plt.scatter(x,y)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 3. Histogram

# %%
plt.hist(x,bins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-888c8b984b29> in <cell line: 1>()
# ----> 1 plt.hist(x,bins)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 4. Bar Plot

# %%
plt.bar(x,height)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-481bbdb88bb8> in <cell line: 1>()
# ----> 1 plt.bar(x,height)
#
# NameError: name 'x' is not defined

# %% [markdown]
# 5. Pseudo Color Plot

# %%
plt.pcolor(C)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-196032110af8> in <cell line: 1>()
# ----> 1 plt.pcolor(C)
#
# NameError: name 'C' is not defined

# %% [markdown]
# ## seaborn functions

# %% [markdown]
# 1. Regression plot

# %%
sns.regplot(x = 'header_1', y = 'header_2', data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-909ef09c5d25> in <cell line: 1>()
# ----> 1 sns.regplot(x = 'header_1', y = 'header_2', data=df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# 2. Box and whisker plot

# %% [markdown]
# 3. Residual Plot

# %%
sns.residplot(data=df, x='header_1', y='header_2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a7ade05be476> in <cell line: 1>()
# ----> 1 sns.residplot(data=df, x='header_1', y='header_2')
#
# NameError: name 'df' is not defined

# %%
# Alternatively
sns.residplot(x=df['header_1'], y=df['header_2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-07f046a05842> in <cell line: 2>()
#       1 # Alternatively
# ----> 2 sns.residplot(x=df['header_1'], y=df['header_2'])
#
# NameError: name 'df' is not defined

# %% [markdown]
# 4. KDE plot

# %%
sns.kdeplot(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-83360fd28913> in <cell line: 1>()
# ----> 1 sns.kdeplot(X)
#
# NameError: name 'X' is not defined

# %% [markdown]
# 5. Distribution Plot

# %%
sns.distplot(X,hist=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-febe5ef5908f> in <cell line: 1>()
# ----> 1 sns.distplot(X,hist=False)
#
# NameError: name 'X' is not defined
