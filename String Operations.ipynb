# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# **Bold**
# _Italic_
# Table
# -------
# |Contents|
# -list 1
# -list 2

# %% [markdown]
# # String Operation

# %%
# Use quotation marks for defining string
"Michael Jackson"
'Michael Jackson'
'1 2 3 4 5 6'          # Digitals and spaces in string
'@#2_#]&*^%$'          # Special characters in string
# Out:
# '@#2_#]&*^%$'

# %%
# Print the string
print("Hello!")
# Out:
# Hello!

# %%
# Assign string to variable
name = "Michael Jackson"

# %% [markdown]
# ## Indexing

# %%
# Indexing starts at 0, first index is on the index 0.
# Print the first & 7th & 14th element in the string
print(name[0])
print(name[6])
print(name[13])
# Out:
# M
# l
# o

# %%
# Negative Indexing
# Last element is given by the index -1
print(name[-1])
print(name[-15])
# Out:
# n
# M

# %%
# Find the length of string
len("Michael Jackson")
# Out:
# 15

# %% [markdown]
# ## Slicing

# %%
name = "Michael Jackson"
name[0:4]
# Out:
# 'Mich'

# %%
name[8:12]
# Out:
# 'Jack'

# %% [markdown]
# ## Stride

# %%
# Get every second element. The element on index 1,3,5...
name[::2]
# Out:
# 'McalJcsn'

# %%
# Get every second element in the range from index 0 to index 4
name[0:5:2]
# Out:
# 'Mca'

# %% [markdown]
# # Strip

# %%
# Removes leading/trailing whitespace.
name1 = "Michael Jackson  "
name2 = name1.strip()
print(name2)
# Out:
# Michael Jackson

# %% [markdown]
# ## Concatenate Strings

# %%
# Concatenate or Combine two strings
statement = name + " is the best"
statement
# Out:
# 'Michael Jackson is the best'

# %%
# Print the string for 3 times
3 * "Michael Jackson"
# Out:
# 'Michael JacksonMichael JacksonMichael Jackson'

# %%
# Concatenate strings
name = "Michael Jackson"
name = name + " is the best"
name
# Out:
# 'Michael Jackson is the best'

# %% [markdown]
# ## Escape Sequences

# %%
# New line escape sequene
print("Michael Jackson \n is the best")
# Out:
# Michael Jackson
#  is the best

# %%
# Tab escape sequence
print("Michael Jackson \t is the best")
# Out:
# Michael Jackson 	 is the best

# %%
# Include back slash in string
print("Michael Jackson \\ is the best")
print(r"Michael Jackson \ is the best")
# Out:
# Michael Jackson \ is the best
# Michael Jackson \ is the best

# %% [markdown]
# ## String Manipulation Operations

# %%
# Convert all the characters in string to upper case
a = "Thriller is the sixth studio album"
print("before upper:", a)
b = a.upper()
print("after upper:", b)
# Out:
# before upper: Thriller is the sixth studio album
# after upper: THRILLER IS THE SIXTH STUDIO ALBUM

# %%
# Replace the old substring with the new target substring is the segment has found in the string
a = "Michael Jackson is the best"
b = a.replace('Michael', 'Janet')
b
# Out:
# 'Janet Jackson is the best'

# %%
# Find the substring in the string.
#Only the index of the first element of substring in string will be the output
name = "Michael Jackson"
name.find('el')
# Out:
# 5

# %%
name.find('Jack')
# Out:
# 8

# %%
# If cannot find the substring in the string then output will be -ve 1
name.find('Jasdfasdasdf')
# Out:
# -1

# %%
# Split the substring into list
name = "Michael Jackson"
split_string = (name.split())
split_string
# Out:
# ['Michael', 'Jackson']

# %% [markdown]
# # RegEx (Regular Expression)

# %%
# Python provides a built-in module called re, which allows you to work with regular expressions.
import re

# %% [markdown]
# The search() function searches for specified patterns within a string. Here is an example that explains how to use the search() function to search for the word "Jackson" in the string "Michael Jackson is the best".

# %%
s1 = "Michael Jackson is the best"

# define the pattern to search for
pattern = r"Jackson"

# Use the search() function to search for the pattern in the string
result = re.search(pattern, s1)

# Check if a match was found
if result:
  print("Match found!")
else:
  print("Match not found.")
# Out:
# Match found!

# %% [markdown]
# Regular expressions (RegEx) are patterns used to match and manipulate strings of text. There are several special sequences in RegEx that can be used to match specific characters or patterns.

# %% [markdown]
# |Special Sequence | Meaning |	Example|
# |-----------------|---------|--------|
# |\d|Matches any digit character (0-9)|"123" matches "\d\d\d"|
# |\D|Matches any non-digit character|"hello" matches "\D\D\D\D\D"|
# |\w	|Matches any word character (a-z, A-Z, 0-9, and _)	|"hello_world" matches "\w\w\w\w\w\w\w\w\w\w\w"|
# |\W	|Matches any non-word character |	"@#$%" matches "\W\W\W\W"|
# |\s	|Matches any whitespace character (space, tab, newline, etc.)	|"hello world" matches "\w\w\w\w\w\s\w\w\w\w\w"|
# |\S	|Matches any non-whitespace character	|"hello_world" matches "\S\S\S\S\S\S\S\S\S"|
# |\b	|Matches the boundary between a word character and a non-word character	|"cat" matches "\bcat\b" in "The cat sat on the mat"|
# |\B	|Matches any position that is not a word boundary	|"cat" matches "\Bcat\B" in "category" but not in "The cat sat on the mat"|

# %%
pattern = r"\d\d\d\d\d\d\d\d\d\d"   # Matches any ten consecutive digits
text = "My Phone number is 1234567890"
match = re.search(pattern, text)

if match:
  print("Phone number found:", match.group())
else:
  print("No match")
# Out:
# Phone number found: 1234567890

# %%
pattern = r"\W"    # Matches any non-word character
text = "Hello, world!"
matches = re.findall(pattern, text)    #The findall() function finds all occurrences of a specified pattern within a string.
print("Matches:", matches)
# Out:
# Matches: [',', ' ', '!']

# %%
s2 = "Michael Jackson was a singer and known as the 'King of Pop'"


# Use the findall() function to find all occurrences of the "as" in the string
result = re.findall("as", s2)

# Print out the list of matched words
print(result)
# Out:
# ['as', 'as']

# %%
# Use the split function to split the string by the "\s"
split_array = re.split("\s", s2)

# The split_array contains all the substrings, split by whitespace characters
print(split_array)
# Out:
# ['Michael', 'Jackson', 'was', 'a', 'singer', 'and', 'known', 'as', 'the', "'King", 'of', "Pop'"]

# %%
# Define the regular expression pattern to search for
pattern = r"King of Pop"

# Define the replacement string
replacement ="legend"

# Use the sub function to replace the pattern with the replacement string
new_string = re.sub(pattern, replacement, s2, flags=re.IGNORECASE)

# The new string contains the origial string with the pattern replaced by the replacement string
print(new_string)
# Out:
# Michael Jackson was a singer and known as the 'legend'

# %% [markdown]
# # Quiz on Strings

# %%
a = "1"
b = "2"
c = a + b
print(c)
# Out:
# 12

# %%
# Use slicing to print out the first three elements:
d = "ABCDEFG"
d[0:3]
# Out:
# 'ABC'

# %%
# Use a stride value of 2 to print out every second character of the string e
e = 'clocrkr1e1c1t'
e[::2]
# Out:
# 'correct'

# %%
# Print out a backslash
print("\\")         # OR
print(r"\ ")
# Out:
# \
# \

# %%
# Convert the variable f to uppercase
f = "You are wrong"
f.upper()
# Out:
# 'YOU ARE WRONG'

# %%
# Convert the variable f2 to lowercase
f2 = "YOU ARE RIGHT"
f2.lower()
# Out:
# 'you are right'

# %%
# find the first index of the sub-string snow
g = " Mary had a little lamb Little lamb, little lamb Mary had a little lamb \
Its fleece was white as snow And everywhere that Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go"
g.find("snow")
# Out:
# 96

# %%
# replace the sub-string Mary with Bob
g.replace("Mary", "Bob")
# Out:
# ' Bob had a little lamb Little lamb, little lamb Bob had a little lamb Its fleece was white as snow And everywhere that Bob went, Bob went Everywhere that Bob went The lamb was sure to go'

# %%
# replace the sub-string , with .
g.replace(",",".")
# Out:
# ' Mary had a little lamb Little lamb. little lamb Mary had a little lamb Its fleece was white as snow And everywhere that Mary went. Mary went Everywhere that Mary went The lamb was sure to go'

# %%
# split the substring to list
g.split()
# Out:
# ['Mary',
#  'had',
#  'a',
#  'little',
#  'lamb',
#  'Little',
#  'lamb,',
#  'little',
#  'lamb',
#  'Mary',
#  'had',
#  'a',
#  'little',
#  'lamb',
#  'Its',
#  'fleece',
#  'was',
#  'white',
#  'as',
#  'snow',
#  'And',
#  'everywhere',
#  'that',
#  'Mary',
#  'went,',
#  'Mary',
#  'went',
#  'Everywhere',
#  'that',
#  'Mary',
#  'went',
#  'The',
#  'lamb',
#  'was',
#  'sure',
#  'to',
#  'go']

# %%
# find whether the digit is present or not using the \d and search() function
s3 = "House number- 1105"
result=re.search("\d", s3)

if result:
  print("Digit found")
else:
  print("Digit not found.")
# Out:
# Digit found

# %%
# replace the sub-string fox with bear using sub() function
str1 = "The quick brown fox jumps over the lazy dog."
new_str1 = re.sub(r"fox","bear", str1)
print(new_str1)
# Out:
# The quick brown bear jumps over the lazy dog.

# %%
# find all the occurrences of woo using findall() function
str2 = "How much wood would a woodchuck chuck, if a woodchuck could chuck wood?"
matches = re.findall(r"woo", str2)
print(matches)
# Out:
# ['woo', 'woo', 'woo', 'woo']

# %% [markdown]
# # Format string

# %%
# f-strings are a new way to format strings in Python.
# They are prefixed with 'f' and use curly braces {} to enclose the variables that will be formatted.
name = "Nidhi"
age = 22
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Nidhi and I am 22 years old.

# %%
# Another way to format string
name = "Nidhi Gohil"
age = 21
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# My name is Nidhi Gohil and I am 21 years old.

# %%
# % Operator
# It uses the % operator to replace variables in the string.
name = "Rahul"
age = 24
print("My name is %s and I am %d years old."%(name,age))
# Out:
# My name is Rahul and I am 24 years old.

# %%
# Additional capabilities
# F-strings are also able to evaluate expressions inside the curly braces
x = 10
y = 20
print(f"The sum of x and y is {x+y}.")
# Out:
# The sum of x and y is 30.
