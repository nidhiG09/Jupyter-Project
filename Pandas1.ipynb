# %% [markdown]
# # Selecting data in Dataframe

# %% [markdown]
# ## Exercise 1: Pandas: DataFrame and Series

# %%
# let us import the Pandas Library
import pandas as pd

# %%
#Define a dictionary 'x'
x = {'Name': ['Rose', 'John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], \
     'Department':['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'],
      'Salary':[100000, 80000, 50000, 60000]}

# Casting the dictionary to a Dataframe
df = pd.DataFrame(x)

# Display the result of
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
#Retrieving the "ID" column and assigning it to a variable x
x = df[['ID']]
x
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
# Check the type of x
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#Retrieving the Department, Salary and ID columns and assigning it to a variable z
z = df[['Department', 'Salary', 'ID']]
z
# Out:
#         Department  Salary  ID
# 0  Architect Group  100000   1
# 1   Software Group   80000   2
# 2      Design Team   50000   3
# 3   Infrastructure   60000   4

# %% [markdown]
# ## Try it yourself

# %%
#  1: Create a dataframe to display the result as below:
a = {'Student': ['David', 'Samuel', 'Terry', 'Evan'], 'Age': [27,24,22,32], 'Country': ['UK', 'Canada', 'China', 'USA'],\
     'Course':['Python', 'Data Structures', 'Machine Learning', 'Web Development'], 'Marks':[85,72,89,76]}
df1=pd.DataFrame(a)
df1
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samuel   24  Canada   Data Structures     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %%
# 2: Retrieve the Marks column and assign it to a variable b
b = df1[['Marks']]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
# 3: Retrieve the Country and Course columns and assign it to a variable c
c = df1[['Country', 'Course']]
c
# Out:
#   Country            Course
# 0      UK            Python
# 1  Canada   Data Structures
# 2   China  Machine Learning
# 3     USA   Web Development

# %% [markdown]
# To view the column as a series, just use one bracket:

# %%
# Get the Student column as a series Object
x = df1['Student']
x
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %% [markdown]
# ## Exercise 2: loc() and iloc() functions

# %%
# Access the value on the first row and the first column
df.iloc[0,0]
# Out:
# 'Rose'

# %%
# Access the value on the first row and the third column
df.iloc[0,2]
# Out:
# 'Architect Group'

# %%
# Access the column using the name
df.loc[0, 'Salary']
# Out:
# 100000

# %%
# Let us create a new dataframe called 'df2' and assign 'df' to it. Now, let us set the "Name" column as an index column using the method set_index().
df2=df
df2=df2.set_index("Name")

# %%
df2.head()
# Out:
#       ID       Department  Salary
# Name
# Rose   1  Architect Group  100000
# John   2   Software Group   80000
# Jane   3      Design Team   50000
# Mary   4   Infrastructure   60000

# %%
df2.loc['Jane', 'Salary']
# Out:
# 50000

# %% [markdown]
# ## Try it yourself

# %%
# Use the loc() function,to get the Department of Jane in the newly created dataframe df2.
df2.loc['Jane', 'Department']
# Out:
# 'Design Team'

# %%
# Use the iloc() function to get the Salary of Mary in the newly created dataframe df2.
df2.iloc[3,2]
# Out:
# 60000

# %% [markdown]
# ## Exercise 3: Slicing

# %%
# let us do the slicing using old dataframe df
df.iloc[0:2, 0:3]
# Out:
#    Name  ID       Department
# 0  Rose   1  Architect Group
# 1  John   2   Software Group

# %%
#let us do the slicing using loc() function on new dataframe df2
#where index column is Name having labels: Rose, John and Jane
df2.loc['Rose':'Jane', 'ID':'Department']
# Out:
#       ID       Department
# Name
# Rose   1  Architect Group
# John   2   Software Group
# Jane   3      Design Team

# %% [markdown]
# ## Try it yourself

# %%
# using loc() function, do slicing on old dataframe df to retrieve
# the Name, ID and department of index column having labels as 2,3
df.loc[2:3, 'Name':'Department']
# Out:
#    Name  ID      Department
# 2  Jane   3     Design Team
# 3  Mary   4  Infrastructure
